# %%
import os
import re
import json
import anew
import string
import nltk
import spacy
import pandas as pd
from nltk.corpus import stopwords
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
from sklearn.preprocessing import MinMaxScaler
from gensim.models import Phrases

# %%
pd.set_option('display.max_colwidth', -1)
stop_words_eng = set(stopwords.words('english'))
te = TransactionEncoder()
scaler = MinMaxScaler(feature_range=(1,10))
nlp = spacy.load('en_core_web_sm')

# %%
#input_doc_path = "./data/tweets_nestle_2016-07-23_2018-07-23.json"
input_doc_path = "./data/tweets_sample.json"

with open(input_doc_path,"r") as f:
    if input_doc_path.endswith(".json"):
        doc = [json.loads(line) for line in f]
    elif input_doc_path.endswith(".csv"):
        doc = pd.read_csv(f, delimiter=',')

# %%
doc = pd.DataFrame(doc)

# %%
# rename column names to standardize data schema
doc = doc.rename(columns={"id_reference_num":"id","delivery":"source","username":"source","tweet":"text"})

# %%
#doc[["tweet","mentions"]].head(10)
# only select key columns and ignore rest of the dataset
doc = doc[["id","source","date","text"]]
doc.head()
# Out:
#                    id          source        date  \
# 0  757000564941160448  UrsulaPflug     2016-07-23
# 1  756998556729348096  nhCoco          2016-07-23
# 2  756997874760749058  samanthashahi   2016-07-23
# 3  756997317086044160  DRCSBoivin      2016-07-23
# 4  756997063855013892  funkyourmother  2016-07-23
#
#                                                                                                                                                              text
# 0  .@Kathleen_Wynne: Stop letting @Nestlé suck Ontario dry for $3.71 per million litres of water  http://d.shpg.org/216672624t
# 1  @ConagraFoods @pepsi Tell @Pepsi @GeneralMills @KelloggsUS @ConAgraFoods @Nestle you want on-package GMO labels, not QR codes | @ewg |  http://bit.ly/29KHaqC
# 2  Hey @Nestle - California is in a drought and you're using our water, can you stop? Oh, we're on fire too  pic.twitter.com/O6jdQFHKUv
# 3  .@Kathleen_Wynne: Stop letting @Nestlé suck Ontario dry for $3.71 per million litres of water  http://d.shpg.org/216671109t
# 4  I like the notion that everyone in Europe started coping with Brexit by eating @Nestle chocolate  pic.twitter.com/7YUYPVIJZK

# %%
"""
def extract_hashtag(x):
    ht_ls = re.findall(r"#(\w+)", x)     # find hashtag
    return list(set(ht_ls))

doc["hashtags"] = doc["text"].apply(lambda x: extract_hashtag(x))
"""
# Out:
# '\ndef extract_hashtag(x):\n    ht_ls = re.findall(r"#(\\w+)", x)     # find hashtag\n    return list(set(ht_ls))\n\ndoc["hashtags"] = doc["text"].apply(lambda x: extract_hashtag(x))\n'

# %%
exclude_punctuation = set([p for p in string.punctuation if p not in ["!",",",".","?",";"]])
# remove mentions, url, hashtag
def strip_text(t):
    #t = re.sub(r'\.?@\w+\:?',"",t)
    t = re.sub(r'\d+','',t)
    t = re.sub('https?://.+',"",t)             # url
    t = re.sub('pic\.twitter\.com.+',"",t)     # url
    t = re.sub("[#]", " ", t)                  # remove hashtag
    #t = t.lower()                              # lower case
    return ''.join(ch for ch in t if ch not in exclude_punctuation)   # remove unnessary punctuation

doc["text_clean"] = doc["text"].apply(lambda x: strip_text(x))

# %%
doc.head()
# Out:
#                    id          source        date  \
# 0  757000564941160448  UrsulaPflug     2016-07-23
# 1  756998556729348096  nhCoco          2016-07-23
# 2  756997874760749058  samanthashahi   2016-07-23
# 3  756997317086044160  DRCSBoivin      2016-07-23
# 4  756997063855013892  funkyourmother  2016-07-23
#
#                                                                                                                                                              text  \
# 0  .@Kathleen_Wynne: Stop letting @Nestlé suck Ontario dry for $3.71 per million litres of water  http://d.shpg.org/216672624t
# 1  @ConagraFoods @pepsi Tell @Pepsi @GeneralMills @KelloggsUS @ConAgraFoods @Nestle you want on-package GMO labels, not QR codes | @ewg |  http://bit.ly/29KHaqC
# 2  Hey @Nestle - California is in a drought and you're using our water, can you stop? Oh, we're on fire too  pic.twitter.com/O6jdQFHKUv
# 3  .@Kathleen_Wynne: Stop letting @Nestlé suck Ontario dry for $3.71 per million litres of water  http://d.shpg.org/216671109t
# 4  I like the notion that everyone in Europe started coping with Brexit by eating @Nestle chocolate  pic.twitter.com/7YUYPVIJZK
#
#                                                                                                                       text_clean
# 0  .KathleenWynne Stop letting Nestlé suck Ontario dry for . per million litres of water
# 1  ConagraFoods pepsi Tell Pepsi GeneralMills KelloggsUS ConAgraFoods Nestle you want onpackage GMO labels, not QR codes  ewg
# 2  Hey Nestle  California is in a drought and youre using our water, can you stop? Oh, were on fire too
# 3  .KathleenWynne Stop letting Nestlé suck Ontario dry for . per million litres of water
# 4  I like the notion that everyone in Europe started coping with Brexit by eating Nestle chocolate

# %%
"""
# SpaCy entity labels
PERSON	People, including fictional.
NORP	Nationalities or religious or political groups.
FAC	Buildings, airports, highways, bridges, etc.
ORG	Companies, agencies, institutions, etc.
GPE	Countries, cities, states.
LOC	Non-GPE locations, mountain ranges, bodies of water.
PRODUCT	Objects, vehicles, foods, etc. (Not services.)
EVENT	Named hurricanes, battles, wars, sports events, etc.
WORK_OF_ART	Titles of books, songs, etc.
LAW	Named documents made into laws.
LANGUAGE	Any named language.
DATE	Absolute or relative dates or periods.
TIME	Times smaller than a day.
PERCENT	Percentage, including "%".
MONEY	Monetary values, including unit.
QUANTITY	Measurements, as of weight or distance.
ORDINAL	"first", "second", etc.
CARDINAL	Numerals that do not fall under another type.
"""
# Out:
# '\n# SpaCy entity labels\nPERSON\tPeople, including fictional.\nNORP\tNationalities or religious or political groups.\nFAC\tBuildings, airports, highways, bridges, etc.\nORG\tCompanies, agencies, institutions, etc.\nGPE\tCountries, cities, states.\nLOC\tNon-GPE locations, mountain ranges, bodies of water.\nPRODUCT\tObjects, vehicles, foods, etc. (Not services.)\nEVENT\tNamed hurricanes, battles, wars, sports events, etc.\nWORK_OF_ART\tTitles of books, songs, etc.\nLAW\tNamed documents made into laws.\nLANGUAGE\tAny named language.\nDATE\tAbsolute or relative dates or periods.\nTIME\tTimes smaller than a day.\nPERCENT\tPercentage, including "%".\nMONEY\tMonetary values, including unit.\nQUANTITY\tMeasurements, as of weight or distance.\nORDINAL\t"first", "second", etc.\nCARDINAL\tNumerals that do not fall under another type.\n'

# %%
# extract entities
LABEL_INCLUDED = ["PERSON","NORP","ORG","GPE","PRODUCT","EVENT","WORK_OF_ART","LAW","LANGUAGE"]
#LABEL_INCLUDED = ["GPE"]
def extract_NER(x):
    doc = nlp(str(x))
    return [(ent.text,ent.label_) for ent in doc.ents if ent.label_ in LABEL_INCLUDED and ent.text.strip() != ""]

doc["entities"] = doc["text_clean"].apply(lambda x: extract_NER(x))

# %%
doc.head()
# Out:
#                    id          source        date  \
# 0  757000564941160448  UrsulaPflug     2016-07-23
# 1  756998556729348096  nhCoco          2016-07-23
# 2  756997874760749058  samanthashahi   2016-07-23
# 3  756997317086044160  DRCSBoivin      2016-07-23
# 4  756997063855013892  funkyourmother  2016-07-23
#
#                                                                                                                                                              text  \
# 0  .@Kathleen_Wynne: Stop letting @Nestlé suck Ontario dry for $3.71 per million litres of water  http://d.shpg.org/216672624t
# 1  @ConagraFoods @pepsi Tell @Pepsi @GeneralMills @KelloggsUS @ConAgraFoods @Nestle you want on-package GMO labels, not QR codes | @ewg |  http://bit.ly/29KHaqC
# 2  Hey @Nestle - California is in a drought and you're using our water, can you stop? Oh, we're on fire too  pic.twitter.com/O6jdQFHKUv
# 3  .@Kathleen_Wynne: Stop letting @Nestlé suck Ontario dry for $3.71 per million litres of water  http://d.shpg.org/216671109t
# 4  I like the notion that everyone in Europe started coping with Brexit by eating @Nestle chocolate  pic.twitter.com/7YUYPVIJZK
#
#                                                                                                                       text_clean  \
# 0  .KathleenWynne Stop letting Nestlé suck Ontario dry for . per million litres of water
# 1  ConagraFoods pepsi Tell Pepsi GeneralMills KelloggsUS ConAgraFoods Nestle you want onpackage GMO labels, not QR codes  ewg
# 2  Hey Nestle  California is in a drought and youre using our water, can you stop? Oh, were on fire too
# 3  .KathleenWynne Stop letting Nestlé suck Ontario dry for . per million litres of water
# 4  I like the notion that everyone in Europe started coping with Brexit by eating Nestle chocolate
#
#                                                                                           entities
# 0  []
# 1  [(ConagraFoods, ORG), (Tell, ORG), (Pepsi, ORG), (GeneralMills, ORG), (Nestle, ORG), (QR, ORG)]
# 2  [(California, GPE)]
# 3  []
# 4  [(Brexit, ORG), (Nestle, ORG)]

# %%
doc.dtypes
# Out:
# id            int64
# source        object
# date          object
# text          object
# text_clean    object
# entities      object
# dtype: object

# %%
"""
from gensim.models import Phrases
documents = ["the mayor of new york was there", "machine learning can be useful sometimes","new york mayor was present"]

sentence_stream = [doc.split(" ") for doc in documents]
bigram = Phrases(sentence_stream, min_count=1, threshold=2)
sent = [u'the', u'mayor', u'of', u'new', u'york', u'was', u'there']
print(bigram[sent])
"""
# Out:
# '\nfrom gensim.models import Phrases\ndocuments = ["the mayor of new york was there", "machine learning can be useful sometimes","new york mayor was present"]\n\nsentence_stream = [doc.split(" ") for doc in documents]\nbigram = Phrases(sentence_stream, min_count=1, threshold=2)\nsent = [u\'the\', u\'mayor\', u\'of\', u\'new\', u\'york\', u\'was\', u\'there\']\nprint(bigram[sent])\n'

# %%
# combine key entities, mentions and hashtag for affinity analysis
def entity_combined(row):
    #ents = ["@"+x.strip() for x in row["mentions"].split(",")]
    #ents = ["#"+x.strip() for x in row["hashtags"]]
    ents = []
    ents.append(row["source"])
    for e in row["entities"]:
        ents.append(e[0].strip())
    return list(set(ents))

doc["entity_combined"] = doc.apply(entity_combined,axis=1)

# %%
doc.head()
# Out:
#                    id          source        date  \
# 0  757000564941160448  UrsulaPflug     2016-07-23
# 1  756998556729348096  nhCoco          2016-07-23
# 2  756997874760749058  samanthashahi   2016-07-23
# 3  756997317086044160  DRCSBoivin      2016-07-23
# 4  756997063855013892  funkyourmother  2016-07-23
#
#                                                                                                                                                              text  \
# 0  .@Kathleen_Wynne: Stop letting @Nestlé suck Ontario dry for $3.71 per million litres of water  http://d.shpg.org/216672624t
# 1  @ConagraFoods @pepsi Tell @Pepsi @GeneralMills @KelloggsUS @ConAgraFoods @Nestle you want on-package GMO labels, not QR codes | @ewg |  http://bit.ly/29KHaqC
# 2  Hey @Nestle - California is in a drought and you're using our water, can you stop? Oh, we're on fire too  pic.twitter.com/O6jdQFHKUv
# 3  .@Kathleen_Wynne: Stop letting @Nestlé suck Ontario dry for $3.71 per million litres of water  http://d.shpg.org/216671109t
# 4  I like the notion that everyone in Europe started coping with Brexit by eating @Nestle chocolate  pic.twitter.com/7YUYPVIJZK
#
#                                                                                                                       text_clean  \
# 0  .KathleenWynne Stop letting Nestlé suck Ontario dry for . per million litres of water
# 1  ConagraFoods pepsi Tell Pepsi GeneralMills KelloggsUS ConAgraFoods Nestle you want onpackage GMO labels, not QR codes  ewg
# 2  Hey Nestle  California is in a drought and youre using our water, can you stop? Oh, were on fire too
# 3  .KathleenWynne Stop letting Nestlé suck Ontario dry for . per million litres of water
# 4  I like the notion that everyone in Europe started coping with Brexit by eating Nestle chocolate
#
#                                                                                           entities  \
# 0  []
# 1  [(ConagraFoods, ORG), (Tell, ORG), (Pepsi, ORG), (GeneralMills, ORG), (Nestle, ORG), (QR, ORG)]
# 2  [(California, GPE)]
# 3  []
# 4  [(Brexit, ORG), (Nestle, ORG)]
#
#                                                  entity_combined
# 0  [UrsulaPflug]
# 1  [Nestle, QR, Tell, Pepsi, nhCoco, GeneralMills, ConagraFoods]
# 2  [California, samanthashahi]
# 3  [DRCSBoivin]
# 4  [funkyourmother, Nestle, Brexit]

# %%
len(doc) # number of tweets
# Out:
# 17107

# %%
ent_list = list(doc["entity_combined"])

# %%
ent_list
# Out:
# [['UrsulaPflug'],
#  ['Nestle', 'QR', 'Tell', 'Pepsi', 'nhCoco', 'GeneralMills', 'ConagraFoods'],
#  ['California', 'samanthashahi'],
#  ['DRCSBoivin'],
#  ['funkyourmother', 'Nestle', 'Brexit'],
#  ['louiseberube'],
#  ['thewindwas'],
#  ['patricklyver'],
#  ['billycbolshevik'],
#  ['INTERPOL', 'trutherbotwhite', 'Nestle'],
#  ['vanessadewson'],
#  ['coref64'],
#  ['kylacopp'],
#  ['KathleenWynne Stop Nestle', 'ONgov', 'CUPE129'],
#  ['Nestle', 'MUFAFUK2patWag'],
#  ['Nestlé', 'Fred Hahn', 'ape_biggles'],
#  ['🍫', 'ChocAero Nestle NestleUKNews', 'Debskat2009'],
#  ['ni_is_she', 'Strawberry Banana'],
#  ['mnkhan88'],
#  ['SOCIAL MEDIA MARKETING', 'Forbes Nestle', 'VERB', 'GOTLUCKIE_COM'],
#  ['Nestle', 'QR', 'jdbrownhall77', 'Pepsi', 'ConagraFoods'],
#  ['TerryRempelMroz'],
#  ['Nestle', 'purdueturfy'],
#  ['kiteie'],
#  ['MC_Thompson'],
#  ['mxdhny66', 'Nestle Nestlees NestleUSA'],
#  ['Nestle', 'QR', 'apollomoniz', 'Pepsi', 'ConagraFoods'],
#  ['GregCameron2'],
#  ['ModernDescartes', 'MaisonCailler'],
#  ['Nestle'],
#  ['AmyDodington'],
#  ['Nestle', 'Kolonel_Azro'],
#  ['BHotton'],
#  ['Nestle', 'Nike', 'Jaroo45'],
#  ['_Tanya_Baldwin_'],
#  ['FrancesDeverell'],
#  ['Nestle',
#   'QR',
#   'leighwyattclark',
#   'Tell',
#   'Pepsi',
#   'GeneralMills',
#   'ConagraFoods'],
#  ['joanneshaw_d2e'],
#  ['beaneroni'],
#  ['Canada', 'Nestle', 'YYC_Alex'],
#  ['Nestle', 'BitchWithA_W', 'LeanCuisine'],
#  ['Nestle', 'geirilja1'],
#  ['Nestle', 'QR', 'JoeWiederhold', 'Pepsi', 'ConagraFoods'],
#  ['timmydietz'],
#  ['KathleenWynne Stop', 'timmydietz'],
#  ['bacciogelato'],
#  ['Retailistan'],
#  ['Maggi', 'Nestle', 'RrrichardZach'],
#  ['HarryRasmussen'],
#  ['QR', 'Nestle', 'Pepsi', 'DevinAnctil', 'ConagraFoods'],
#  ['PalmOilKills RT', 'tammyguess59'],
#  ['Watrdude', 'Nestle', 'QR', 'Tell', 'Pepsi', 'GeneralMills', 'ConagraFoods'],
#  ['Nestle',
#   'QR',
#   'JoeWiederhold',
#   'Tell',
#   'Pepsi',
#   'GeneralMills',
#   'ConagraFoods'],
#  ['LaurenLRogers', 'PhD', 'RT FoodFlavour Interested', 'Nestle BBSRC'],
#  ['Jewninho', 'Nestle'],
#  ['DianeBr05031964'],
#  ['darrylmabee'],
#  ['mikeopseu'],
#  ['TDF', 'Nestle'],
#  ['RSmolenaars'],
#  ['robingras'],
#  ['RobertMcBryde'],
#  ['FredHahnCUPE'],
#  ['Nestle', 'kiamini_martin'],
#  ['RobertMcBryde'],
#  ['PalmOilKills RT', 'kheifa3'],
#  ['Baby Milk Action', 'RuthSmeeth Nestle', 'sigourneybeaver'],
#  ['Ch0coBars', 'Nestle', 'Tryrone'],
#  ['robin_brooksart'],
#  ['Nestle Nestle', 'raza_zaheer'],
#  ['FoodFlavour', 'PhD', 'Nestle BBSRC'],
#  ['RuthSmeeth Nestle', 'sigourneybeaver'],
#  ['TDF', 'Nestle', 'Paris', 'Vittel'],
#  ['Cristina_garcia', 'Nestle'],
#  ['spiritgecko'],
#  ['AliRathore110', 'FruitaVitals Nestle Please'],
#  ['joshyross', 'the Edinburgh Awards', 'Perrier'],
#  ['joshyross', 'NestleWe', 'African Children', 'RuthSmeeths'],
#  ['Nestle RuthSmeeth', 'cornish_jack'],
#  ['99_hp', 'RuthSmeeth Nestle'],
#  ['99_hp', 'RuthSmeeth Nestle'],
#  ['joshyross', 'Nestle', 'RuthSmeeth'],
#  ['ABB CreditSuisse Nestle Novartis Roche UBS', 'Republicans', 'SebRamspeck'],
#  ['tabbykat7281'],
#  ['LexieED'],
#  ['binchareglo'],
#  ['ALiN_013'],
#  ['killbillvol69'],
#  ['Michell27706841'],
#  ['DorothyGithae', 'AkiliDada AkinyiOdongoKE', 'WIF'],
#  ['EyelineImagery'],
#  ['LeafsfanAtiq'],
#  ['jlapolo', 'Nestle'],
#  ['pro_aktv'],
#  ['Bigideasinedu'],
#  ['1Hedgehog1'],
#  ['CocaCola AECOM Nestle', 'cnbcSri'],
#  ['BoomerWarrior'],
#  ['Nestle'],
#  ['corgi_grrl', 'Stop Nestle', 'WallaWalla Valley'],
#  ['towy71', 'Tell Nestle'],
#  ['doremifasx', 'Nestle'],
#  ['wetcoastguy'],
#  ['pgfwave'],
#  ['aitijoyce'],
#  ['lauraemilyanna', 'Nestle'],
#  ['penel_j'],
#  ['The  TDF', 'Nestle', 'Paris'],
#  ['RinekeV',
#   'München',
#   'Nestle RrrichardZach',
#   'the Summer School Mathematical Philosophy'],
#  ['stegglesluke', 'Nestle'],
#  ['stegglesluke', 'Nestle'],
#  ['stegglesluke', 'Nestle'],
#  ['stegglesluke', 'Nestle'],
#  ['stegglesluke', 'Nestle'],
#  ['stegglesluke', 'Nestle'],
#  ['stegglesluke'],
#  ['stegglesluke'],
#  ['stegglesluke', 'Nestle'],
#  ['Nestle', 'BWhackRevBackup', 'New Review'],
#  ['saveonfoods', 'Nestle'],
#  ['michellenagel'],
#  ['CoreyRedekop'],
#  ['MarkDiFelice'],
#  ['Lfcredman1990', 'NestleCare Nestle'],
#  ['rachaelhxx', 'Nestle'],
#  ['Paris', 'Nestle'],
#  ['Outsider', 'MPBorman'],
#  ['Mari_Knox'],
#  ['suzytreehugger'],
#  ['noooismael'],
#  ['kitchy_kraemer'],
#  ['MorganLauraA'],
#  ['Nestle', 'QR', 'uncleshed2', 'Pepsi', 'ConagraFoods'],
#  ['Lfcredman1990', 'Nestle'],
#  ['cbcwatcher8', 'KathleenWynne'],
#  ['AffirmingSexEd'],
#  ['CarrefourFrance', 'Nestle', '1MaNinPariS'],
#  ['olumideakinsola', 'Watched', 'CocaCola AECOM Nestle'],
#  ['wizardweb', 'Nestle'],
#  ['suet0526'],
#  ['😩', '🍬', 'Nestle Quality', 'SianandRob'],
#  ['TopolovecM'],
#  ['Nestle', 'cr360_'],
#  ['acf42d9ae1364c5', 'Tell Nestle'],
#  ['acf42d9ae1364c5', 'Tell Nestle'],
#  ['La France', 'Paris', 'Nestle'],
#  ['tashfainyousuf', 'God Killer', 'NESCAFE U', 'CocaCola Nestle'],
#  ['arcticyaks'],
#  ['UP', 'AndaluzaJASP'],
#  ['SolarImpulse', 'Nestle'],
#  ['joephilly09'],
#  ['LeoraCZ'],
#  ['ShinySuz'],
#  ['HBEndTimesNews', 'Keeps', 'Nestle', 'NoMiloMilo'],
#  ['HBPopTech', 'Keeps', 'Nestle', 'NoMiloMilo'],
#  ['HBMusicWorld', 'Keeps', 'Nestle', 'NoMiloMilo'],
#  ['Keeps', 'Nestle', 'NoMiloMilo', 'HBGoldCoast'],
#  ['Keeps', 'Nestle', 'NoMiloMilo', 'HBPopCult'],
#  ['GlobeHB', 'Keeps', 'Nestle', 'NoMiloMilo'],
#  ['Keeps', 'Nestle', 'NoMiloMilo', 'HBNewsWorld'],
#  ['Keeps', 'Nestle', 'HBChristoAU', 'NoMiloMilo'],
#  ['itsratedjay', 'Nestle'],
#  ['Greengod4good'],
#  ['TourdeFrance', 'NESCAFE Start', 'Nestle', 'Nescafe'],
#  ['Nestle', 'frakikkalp85'],
#  ['AndresMusta'],
#  ['Chikachuko', 'Tell Nestle'],
#  ['Monkeyspit'],
#  ['multiclass_geek'],
#  ['QR', 'Nestle', 'Pepsi', 'LonnieAlbrecht', 'ConagraFoods'],
#  ['LeuiseCrumble',
#   'Nestle',
#   'QR',
#   'Tell',
#   'Pepsi',
#   'GeneralMills',
#   'ConagraFoods'],
#  ['applefreakemily', 'Nestle'],
#  ['Nestle',
#   'QR',
#   'Tell',
#   'Pepsi',
#   'Steppen__Wolf',
#   'GeneralMills',
#   'ConagraFoods'],
#  ['Nestle',
#   'QR',
#   'Tell',
#   'Pepsi',
#   'kennethjgilmour',
#   'GeneralMills',
#   'ConagraFoods'],
#  ['NestleFamilySweeps', 'Nestle', 'marierose112680'],
#  ['Danone', 'KJOsinga', 'Lactalis', 'Nestle'],
#  ['Nestle', 'QR', 'hashowug', 'Pepsi', 'ConagraFoods'],
#  ['Nestle', 'QR', 'hashowug', 'Tell', 'Pepsi', 'GeneralMills', 'ConagraFoods'],
#  ['ajann1983'],
#  ['Nestle', 'QR', 'Pepsi', 'GblinqT', 'ConagraFoods'],
#  ['Scotthannah42Sh', 'Nestle', 'McCoys', 'Yorkie'],
#  ['Zarbars'],
#  ['Nestle',
#   'QR',
#   'Tell',
#   'Pepsi',
#   'GeneralMills',
#   'ConagraFoods',
#   'wgonzalezgarcia'],
#  ['bRAVE_slaveS', 'Nestle', 'Grant'],
#  ['BluffsCat'],
#  ['Nestle', 'QR', 'Tell', 'Heimpy', 'Pepsi', 'GeneralMills', 'ConagraFoods'],
#  ['holistic_annie', 'Nigella'],
#  ['Nestle',
#   'QR',
#   'Tell',
#   'Pepsi',
#   'GeneralMills',
#   'aboutreed',
#   'ConagraFoods'],
#  ['lindsaybm5'],
#  ['nowisthesecret'],
#  ['Nestle',
#   'QR',
#   'Tell',
#   'Pepsi',
#   'GeneralMills',
#   'PegHeronHeidel',
#   'ConagraFoods'],
#  ['Al_Bender'],
#  ['marilynrutten'],
#  ['Colleen', 'Nestle', 'LeanCuisine'],
#  ['iowanebraskaspa'],
#  ['iowanebraskaspa'],
#  ['___D___O___M___', 'Nestle'],
#  ['DagmaraGuy'],
#  ['Water', 'Nestle', 'cityos'],
#  ['Nestle',
#   'QR',
#   'Tell',
#   'Pepsi',
#   'GeneralMills',
#   'GunemJFunk',
#   'ConagraFoods'],
#  ['MarianeYvonne'],
#  ['MarianeYvonne'],
#  ['KathleenWynne Stop', 'MarianeYvonne'],
#  ['radicpunk'],
#  ['haywoodustfu', 'Nestle LeanCuisine'],
#  ['Nestle', 'kxthryndxffy'],
#  ['QR', 'Nestle', 'OrganicFan2', 'Pepsi', 'ConagraFoods'],
#  ['Nestle',
#   'QR',
#   'Tell',
#   'Pepsi',
#   'JoeyHawkLeftow',
#   'GeneralMills',
#   'ConagraFoods'],
#  ['LaterHomie', 'NestleCA Nestle'],
#  ['Nestle',
#   'QR',
#   'AlternativeMedi',
#   'Tell',
#   'Pepsi',
#   'GeneralMills',
#   'ConagraFoods'],
#  ['Nestle', 'CustardTrout'],
#  ['WendyinPR', 'Nestle'],
#  ['Nestle',
#   'QR',
#   'Melek__Korel',
#   'Tell',
#   'Pepsi',
#   'GeneralMills',
#   'ConagraFoods'],
#  ['theoverlordunit'],
#  ['ugly_artwork'],
#  ['Nestle',
#   'QR',
#   'Tell',
#   'GhostWolfWalker',
#   'Pepsi',
#   'GeneralMills',
#   'ConagraFoods'],
#  ['Nestle', 'culinarydiplo'],
#  ['Nestle',
#   'QR',
#   'Tell',
#   'Pepsi',
#   'GeneralMills',
#   'FedUPwGovtLies',
#   'ConagraFoods'],
#  ['Nestle',
#   'QR',
#   'Tell',
#   'Pepsi',
#   'GeneralMills',
#   'titicelia51',
#   'ConagraFoods'],
#  ['Nestle', 'QR', 'Pepsi', 'tristamshanty', 'ConagraFoods'],
#  ['Nestle', 'QR', 'poaxtly', 'Pepsi', 'ConagraFoods'],
#  ['Lindon_linda',
#   'Nestle',
#   'QR',
#   'Tell',
#   'Pepsi',
#   'GeneralMills',
#   'ConagraFoods'],
#  ['Nestle', 'robb2012', 'QR', 'Tell', 'Pepsi', 'GeneralMills', 'ConagraFoods'],
#  ['BonWin'],
#  ['Nestle', 'wdspattmuscol'],
#  ['PhilHoganEU', 'Nestle', 'SimonaPresenti1', 'FOODEU', 'Moedas'],
#  ['NestleSA Nestle', 'magdafew1969'],
#  ['Nestle', 'smarthealthlab'],
#  ['Break',
#   'Kit Kat',
#   'Nestle Social Media',
#   'Susan Dolan GoogleExpertUK',
#   'AlirisZ'],
#  ['Kit Kat', 'GoogleExpertUK', 'Nestle Social Media'],
#  ['karenblumel', 'Nestle Heres'],
#  ['staff236'],
#  ['Nestle', 'BreakAway', 'Its_aiden'],
#  ['Tell Nestle', 'NatsukiCHIDOYA'],
#  ['nosiaj', 'Ontario'],
#  ['edibleTORONTO', 'San Pellegrino', 'Nestle'],
#  ['edibleTORONTO', 'KathleenWynne Stop'],
#  ['lifeboogie'],
#  ['flagcomm', 'FoodWaste', 'Nestle'],
#  ['_bekahmv'],
#  ['Nestle',
#   'thomaSchulz',
#   '😎',
#   'Barcelona',
#   'CoC',
#   'Nestlees ZurichESprensa ZurichSeguros',
#   'Zurich'],
#  ['pward5'],
#  ['IcelandFoods', 'DigitalLPack', 'Tesco Nestle'],
#  ['Barcelona', 'Codourey', 'thomaSchulz', 'Nestles'],
#  ['SabineSchaefers', 'Nestle'],
#  ['Nestle', 'the Open Innovation Platform', 'NESTLE_DAT'],
#  ['.Nestle', 'BarcelonaGlobal', 'Barcelona'],
#  ['WillsmerWagg', 'KirintecLtd', 'Nestle'],
#  ['thespinksjinx'],
#  ['Nestle Nestles', 'zarkanelaelena'],
#  ['Nestle', 'Paul Bulcke', 'dmexco'],
#  ['Nestle'],
#  ['Nestle', 'DaniedmundsDani', 'Procrastination'],
#  ['HBNewsWorld'],
#  ['Nestle', 'holler303'],
#  ['Nestle', 'NoMilo', 'Ghostbusters', 'HBNewsWorld'],
#  ['Pranathi1408', 'Market Nestle KerryOfficial'],
#  ['cotec007'],
#  ['zerobaggage'],
#  ['Nestle', 'somekindofkelly'],
#  ['katy_sotomayor'],
#  ['DavieWiseman', 'Yorkie'],
#  ['rothwell_geoff'],
#  ['NestleAcademy', 'Nestle Interns', 'thePisaaa', 'London'],
#  ['UniOfYork', 'serenitykitty'],
#  ['DrMJW', 'NEED', 'STOPO Nestle', 'SK'],
#  ['Megawitch'],
#  ['Nestle', 'Bought', 'catarmstrongdr'],
#  ['KathleenWynne Stop', 'DRdrumming'],
#  ['saveonfoods', 'Nestle'],
#  ['debbytyrrell1'],
#  ['Nestle', 'DougRozen', 'OpenInnovation'],
#  ['SolarImpulse', 'Nestle'],
#  ['StamJeremy'],
#  ['Nestle', 'BearandBobbin'],
#  ['Nestle MMAglobal', 'ccoyle2'],
#  ['Nestle MMAglobal', 'daijapopmobile'],
#  ['100Fists', 'Nestle', 'Nestles'],
#  ['MMAglobal', 'Nestle'],
#  ['MMAglobal', 'Nestle'],
#  ['MMAglobal'],
#  ['daijapopmobile', 'Nestle', 'MMAglobal'],
#  ['Nestle', 'AubLoMobile'],
#  ['NYMM', 'Nestle', 'NYMinuteMag'],
#  ['julietsangchan', 'Pete Nestle'],
#  ['MMAglobal', 'Nestle'],
#  ['samickgirl'],
#  ['mlinto'],
#  ['Nestle', 'KujtimDobruna'],
#  ['💝', 'BarbaraLenhard', 'Nestle'],
#  ['Nestle'],
#  ['Santander SwissPost Nestle', 'IE_Innovation'],
#  ['Summit', 'daijapopmobile', 'MMAglobal', 'Nestle  Audi'],
#  ['Scotthannah42Sh', 'Nestle McCoys'],
#  ['TaquitosDotNet', 'United Kingdom'],
#  ['Nestle', 'McCoys', 'ScotthannahSh'],
#  ['Reeev0', 'Nestle'],
#  ['bradparkin'],
#  ['peachy_diary'],
#  ['Drumstick Nestle', 'LocalItGirl'],
#  ['gabeontheradio', 'Nestle Drumstick', 'GetConed', 'Smores'],
#  ['Yall', 'Laffy Taffy', 'jogusta', 'Cmon Nestle'],
#  ['Syrian', 'WilhelmTell11'],
#  ['Nestle Pure Life Water', 'marrazzosmarket'],
#  ['DaniedmundsDani', 'Nestle CadburyUK'],
#  ['LazyRLizard'],
#  ['TheRealDaveR'],
#  ['SeemaDee'],
#  ['emanuel14486948', 'Nestle'],
#  ['Lol', 'emanuel14486948', 'Nestle'],
#  ['Timothy69562199'],
#  ['emgfind'],
#  ['toothykindness'],
#  ['Newfoodaisle'],
#  ['.Nestle', 'Switzerland', 'wdc_creative'],
#  ['Nestle', 'laceymarchment', 'Tescos'],
#  ['NogueiraRaquelv', 'Nestle', 'NestleSuisseSA Nestle'],
#  ['scottytohotty26', 'Nestle'],
#  ['davek911'],
#  ['Merovingian101', 'Nestle'],
#  ['oruchechuks', 'NestleCareersUK NestleWatersNA Nestle'],
#  ['IE_Cameron', 'Santander SwissPost Nestle'],
#  ['Nestle', 'Digital  Social'],
#  ['SolarImpulse', 'Nestle'],
#  ['MimiWatt0', 'Little Charlie Dunn', 'MailOnline Nestle Seriously'],
#  ['researchmarkets'],
#  ['Nestle', 'TradeArabia'],
#  ['confessedemu'],
#  ['PoundworldTweet'],
#  ['NSonnePedersen', 'Nestle'],
#  ['Nestle', 'NestleBelgium'],
#  ['vixianne', 'Tell Nestle'],
#  ['johnnyferrier69'],
#  ['earthdroplet'],
#  ['Nestle', 'KontikiBizVideo'],
#  ['CA', 'Nestle', 'ThatIsOutRage'],
#  ['Nestle Libertea', 'GroceryMakers LLaws', 'TheGOPJesus'],
#  ['LLaws GroceryMakers', 'ThatIsOutRage', 'Libertea Nestle'],
#  ['Taste Our', 'BoycottNestle', 'LisaCuliner'],
#  ['PositivelyJoan', 'BOYCOTT Nestle', 'TheGOPJesus'],
#  ['LLaws GroceryMakers', 'TheGOPJesus'],
#  ['LeClanFraser', 'TheGOPJesus'],
#  ['KNOW', 'Kelly KlippetyKlop', 'TheGOPJesus'],
#  ['TheGOPJesus'],
#  ['SamanthaSAS DemoFan', 'Nestle', 'CA WATER  POISONING FOOD', 'TheGOPJesus'],
#  ['TheGOPJesus'],
#  ['PositivelyJoan',
#   'LLaws Nestle',
#   'Boycott NestleUSA for Blocking  GMO Labels VirginiaInCal',
#   'FarmFairyCrafts'],
#  ['PalmOilKills RT', 'JanMcDonagh1'],
#  ['PalmOilKills RT', 'tammyguess59'],
#  ['Nestle', 'ceefootball'],
#  ['ender_carrion'],
#  ['MartinWashi'],
#  ['Nestle Greedy', 'ElRoi65'],
#  ['Nestle',
#   'KlippetyKlop',
#   'Solidarity',
#   'Kelly',
#   'EnlightenedOutrage  Transparency',
#   'TheGOPJesus'],
#  ['boxyourbuddy', 'Nestle'],
#  ['crunchytubiemam', 'Nestle'],
#  ['F1_AN', 'UK', 'Nestle'],
#  ['PerryTheMatapus', 'Nestle'],
#  ['de_warahoun'],
#  ['Nestle', 'taxiroute'],
#  ['LouLachat', 'PalmOilKills RT'],
#  ['AlexLFz', 'Nestle'],
#  ['Tesco', 'JoshMash', 'Nestle', 'Angriffhund'],
#  ['Nestle NestleUKNews', 'CadburyUK', 'Tesco', 'Josh_Mash'],
#  ['PalmOilKills RT', 'kheifa3'],
#  ['UrgentVetClinic', 'Nestle', 'TheStringBeanNC', 'FrostyPaws'],
#  ['bens_1989'],
#  ['Brill_RN', 'Nestle'],
#  ['Brill_RN', 'Nestle'],
#  ['Nestle NestleUKNews', 'Tesco', 'Josh_Mash'],
#  ['PurinaCareers', 'Nestle'],
#  ['Raym0nd_Rogers'],
#  ['.Nestle', 'stlbizlkonczal', 'Purina'],
#  ['Sarah_A_Childs'],
#  ['doitdiddy'],
#  ['Elizabe24926344'],
#  ['OUR Food System', 'FarmFairyCrafts'],
#  ['PalmOilKills RT', 'Animantium1'],
#  ['BOYCOTT Nestle', 'LeClanFraser', 'rosevine3'],
#  ['KNOW', 'Kelly KlippetyKlop', 'TheGOPJesus', 'rosevine3'],
#  ['Nestle GF', 'ohsoglutenfree'],
#  ['TheGOPJesus Nestle', 'EatsTreats'],
#  ['rosevine3'],
#  ['SamanthaSAS DemoFan',
#   'BOYCOTT Nestle',
#   'CA WATER  POISONING FOOD',
#   'rosevine3'],
#  ['FlemingSAC', 'NationalIceCreamMonth', 'Nestle'],
#  ['BOYCOTT Nestle', 'rosevine3'],
#  ['sate_yourself', 'Nestle'],
#  ['sparklijelibean', 'Nestle'],
#  ['Yum', 'sparklijelibean'],
#  ['.Nestle',
#   'BoycottNestle',
#   'NolaLightman',
#   'NeverHillary',
#   'StayRidiculous',
#   'ImWithJill'],
#  ['Netherlands', 'Graynnia'],
#  ['turboEco'],
#  ['turboEco'],
#  ['Nestle'],
#  ['FoodGrads'],
#  ['SolarImpulse', 'Nestle', 'ICYMI'],
#  ['RAH_HELL', 'Nestle', 'Nestea'],
#  ['raven_kiara', 'Nestle'],
#  ['Nestle', 'GensuiteLLC'],
#  ['ChildLabour', 'Nestle', 'Nestle Nestlees NestleUSA', 'Mali', '_jcsa'],
#  ['FrostSullivanAP Nestle', 'Piotr_Vitafoods', 'VitafoodsAsia Conf'],
#  ['CaroKelleher', 'FrostSullivanAP Nestle', 'VitafoodsAsia Conf'],
#  ['Nestle', 'tanejasbride'],
#  ['Nestle', 'tanejasbride'],
#  ['Stouffers', 'Nestle', 'DidYouKnow', 'Apollo'],
#  ['Pranathi1408', 'Nestle'],
#  ['youmakemewow'],
#  ['NutritionHealin', 'Tell Nestle'],
#  ['KWBookstore'],
#  ['Nestle Nevermind', 'instorefresh'],
#  ['instorefresh', 'Nestle'],
#  ['Danone', 'Nestle', 'Lactalis', 'askzenith'],
#  ['Danone', 'KathrynZenith', 'Lactalis', 'Nestle'],
#  ['Nestle', 'KITKAT', 'CocoaPlan'],
#  ['somekindofkelly'],
#  ['BodhiHexe2', 'PalmOilKills RT'],
#  ['rsbasavaraj711'],
#  ['Nestle', '6pvrpose'],
#  ['GrabschDagmar', 'PalmOilKills RT'],
#  ['byrnside'],
#  ['BOYCOTT Nestle Blocking',
#   'Labeling!VirginiaInCal',
#   'FarmFairyCrafts',
#   'LLaws'],
#  ['kayserkendra', 'Nestle Coffee'],
#  ['Tony_Storton', 'Nestle'],
#  ['Nestle', 'trutherbotprple', 'nowChairman', 'Peter'],
#  ['happygrambox', 'Nestle'],
#  ['😩', 'kasperhabtie', 'BEFOREHAND', 'DUTCH', 'GRAMMATICALLY'],
#  ['Nestle',
#   'CrawfordFund',
#   'PIMCGIAR',
#   'Daniel Lagger',
#   'IFPRI KarenWoods',
#   'Register'],
#  ['KatMcCub'],
#  ['Nestle'],
#  ['NewFoodMag', 'Nestle'],
#  ['Nestle', 'sulkfiction'],
#  ['FB', 'Nestle', 'Parle –   britannia', '–.', 'KonnectInsights', 'FMCG'],
#  ['FarmFairyCrafts', 'OrganicsFree'],
#  ['OECD', 'Huawei Nestle', 'GAN4Youth', 'GAN'],
#  ['Tesco', 'DLP', 'Nestle', 'DigitalLPack'],
#  ['NescafeAzera Americano', 'Nestle', 'IntegraOffice'],
#  ['Nestle', 'EvaIHurt'],
#  ['PattiAn46409545'],
#  ['Nestle Aero', 'ChrispycreepY'],
#  ['EricHoward84'],
#  ['ihatemegann', 'Nestle I THINK'],
#  ['.Nestle  Grand Bars', 'Steinmoney'],
#  ['Nestle', 'EliseSanzeri', 'juarezkatie44', '😎'],
#  ['BellanWhite FirstKatalyst',
#   'OgilvyAfrica',
#   'Nestle LGUS',
#   'Marketingland',
#   'Kevin_TheGeek',
#   'Ogilvy Awesome'],
#  ['NFFinfo', 'Appreciate', 'WomenWin', 'NhiFFAV', 'Nestle VN', 'FFAVCup'],
#  ['broker_newswire',
#   'Nestle Samsung',
#   'Nestle Team',
#   'Samsung Samsung',
#   'Digital Health And Nutrition'],
#  ['microburin'],
#  ['mdrmuhaimin'],
#  ['christi83353917'],
#  ['CRM', 'Salesforce With New Digital Lab', 'TripathySantosh'],
#  ['Nestle', 'moghraby'],
#  ['ReutersTech', 'Samsung', 'dmcorpaffair', 'Nestle'],
#  ['MagnumUK CadburyUK Nestle', '😜', 'mynameizjames'],
#  ['Gaiasdesigns'],
#  ['Basilstrategies', 'Nestle', 'Collaborate', 'DigitalHealth', 'Samsung'],
#  ['ChaoticShadow', 'Nestle', '4439234d179d485'],
#  ['lovemoney_com'],
#  ['Nestle', 'SamsungSSIC'],
#  ['ashlee'],
#  ['Nestle', 'Hashtagelohel', 'Fajitus'],
#  ['Nestle NestleUKNews',
#   'ChocolateIovers',
#   'SarahBWatsonfan',
#   'MCClubOfficial Aeropostale'],
#  ['TheGOPJesus DemoFan', 'Nestle', 'zeus_bob'],
#  ['CaracciGmc'],
#  ['manelcurado', 'DigitalHealth', 'SamsungSSIC', '.Nestle'],
#  ['HollyFerling',
#   'Nestle Congrats',
#   'ToyotaAus',
#   'BoomSportsMgt',
#   'ASICSaustralia'],
#  ['etrack80', 'TMobile'],
#  ['Digital', 'Nestle', 'New', 'CAforBrands'],
#  ['Jane', 'JaneFarnham'],
#  ['Jane', 'GBVoiceovers'],
#  ['Samsung', 'Nestle', 'VeronaCapital', 'NutritionScience'],
#  ['Nanamommysissy', 'Nestle'],
#  ['DigitalHealth', 'Nestle', 'SamsungSSIC'],
#  ['diana_true'],
#  ['SecretLabeling', 'NationalMilkChocolateDay', 'OurBody', 'ThatIsOutRage'],
#  ['OurFuture', 'BanGMOs', 'FoodSafety', 'ThatIsOutRage'],
#  ['divamama37'],
#  ['Nestle', 'swissnexBoston', 'swissnexSF'],
#  ['LeadinStilettos', 'NationalMilkChocolateDay', 'the Nestle Bunny'],
#  ['Nestle', 'rubinahassan'],
#  ['Nestle', 'litmus108'],
#  ['ShamRang'],
#  ['DemoFan24',
#   'Nestle',
#   'On Record',
#   'Stealing Californias Water',
#   'TheGOPJesus Biggest Drought'],
#  ['Nestle', 'NestléHealthyKids'],
#  ['yudhesha'],
#  ['Nestle Cafedirect', 'EcoffinsUK', 'Fairtrade', 'KITKAT'],
#  ['Kit Kat', 'GoogleExpertUK', 'Nestle Social Media'],
#  ['Nestle', 'JamesBarra1998'],
#  ['Nestle NestleUKNews',
#   'ChocolateIovers',
#   'SarahRe82756439',
#   'MCClubOfficial Aeropostale'],
#  ['Nestle', 'Milkybar Munchies', 'TEZofAllTrades'],
#  ['GamaConsumer', 'Italy Nestle', 'Ore Liete'],
#  ['Cafedirect', 'Fairtrade', 'KITKAT'],
#  ['Mike',
#   'MCClubOfficial Aeropostale Nestle',
#   'Lol',
#   'Eileenec',
#   'ChocolateIovers  Trust'],
#  ['Nestle', '🌽'],
#  ['freckles3', 'Nestle'],
#  ['cplattc'],
#  ['Cafedirect', 'EcoffinsUK', 'Fairtrade', 'Nestle KITKAT'],
#  ['Nestle', 'CadburyWorld LoveSchmitten', 'Bye', 'anujjoc'],
#  ['Promotion', 'marketing_gifts', 'Milo', 'Walter Mart', 'GWP', 'Umbrella'],
#  ['AmyEdwards1982',
#   'Nestle NestleUKNews',
#   'ChocolateIovers',
#   'MCClubOfficial Aeropostale'],
#  ['Nestle', 'BoycottNestle', 'BBoyReeSe', 'Buitoni', 'Bye', 'Barilla'],
#  ['ChocolateIovers',
#   'Mike',
#   'Hertsnatalie',
#   'MCClubOfficial Aeropostale Nestle'],
#  ['alinesmedeiros', 'Nestle', 'Brazil'],
#  ['Nestle', 'HolmCassie'],
#  ['amitsinghal15', 'Nestle Contact'],
#  ['Milo', 'Nestle', 'odmasia'],
#  ['JadedeVries87', 'Nestle Stop', 'Nigella'],
#  ['lizhealey78', 'Nestle ChaoticShadow'],
#  ['Nestle Haha', 'ChaoticShadow24'],
#  ['lizhealey78', 'Nestle ChaoticShadow'],
#  ['Nestle', 'ChaoticShadow'],
#  ['Nestle', 'TheDMAT'],
#  ['Kolkata Nestle NestleIndia',
#   'SurojitMukher15',
#   'Nestle Employee Volunteer Program'],
#  ['elizaelsaian', 'Nutripuffs', 'Cerelacs', 'Nestle Malaysia'],
#  ['UpGyres'],
#  ['Samsung', 'Samsung_RA', 'Nestle'],
#  ['Nestle', 'SamsungSSIC', 'GoKareo', 'HealthyLiving'],
#  ['Daubendiak'],
#  ['SmartContentNws', 'Speed Up', 'New York Office Adweek'],
#  ['purpleactivism',
#   'Nestle',
#   'TheGOPJesus',
#   'ValKirkgaard OrganicsFree RisingSign'],
#  ['.Nestle', 'Rock_Health', 'Samsung'],
#  ['papimamilla', 'Nestle Pleaseclick'],
#  ['Nestle AgResults', 'IFPRImedia', 'WFP', 'CrawfordFund'],
#  ['MathildeVhargon'],
#  ['Nestle', 'itsinmyopinion'],
#  ['IoT', 'Nestle', 'medcitynews'],
#  ['LaurieHerd1'],
#  ['IoT', 'Nestle', 'medcitynews'],
#  ['nversel', 'Nestle', 'IoT'],
#  ['ARTIK', 'Nestle', 'SamsungDC', 'VisionForTech'],
#  ['bnshPmln'],
#  ['Nanamommysissy', 'Nestle'],
#  ['PurinaCareers', 'Nestle'],
#  ['D9forRealChange'],
#  ['D9forRealChange',
#   'Nestle',
#   'DONTSHOPUNTILTHEYSTOP PUT THEM OUT OF BUSINESS',
#   'BlackLivesMatter'],
#  ['️😍', 'NestleRolos', 'Dark', 'Shane_Wint3r', 'Orgasm'],
#  ['Nestle', 'naeemafzal_'],
#  ['Nestle Lindt', 'Cocoa', 'LindtChocolate', 'raghavan1314'],
#  ['Nestle', 'IoT   Nutrition Science to Advance  DigitalHealth', 'AnTanghe'],
#  ['Nestle', 'MattyyyICEe'],
#  ['Nestle', 'taranellroth'],
#  ['the_baDde5t', 'NestleFamilySweeps', 'Brandmovers Nestle'],
#  ['Samsung', 'EIoTinsights'],
#  ['Nestle', 'chocobean123'],
#  ['Amplify', 'Nestle Uses Influencers', 'See', 'Socialyteco'],
#  ['Nestle', 'Nescafé'],
#  ['.Nestle', 'KyleLukan', 'Salesforce'],
#  ['.Nestle', 'adage', 'Salesforce'],
#  ['Kit Kat', 'GoogleExpertUK', 'Nestle Social Media'],
#  ['eerahashir', 'Nestle'],
#  ['Nestle', 'rebel_ss'],
#  ['Nestle', 'Claudia_OStory'],
#  ['johnnyracerR6', 'Nestle', 'Lindt'],
#  ['SamsungSSIC Nestle Cool', 'Medidata'],
#  ['Mövenpick Walnut', 'Nestle', 'Espresso'],
#  ['fredgituthu', 'UNCTAD'],
#  ['BrandsIUse', 'UNCTAD'],
#  ['uberimran', 'Nestle'],
#  ['uberimran', 'Twitter'],
#  ['SmartDevice', 'Nestle', 'smgustavsen'],
#  ['uberimran', 'Nestle'],
#  ['CapitalTristate', 'Nestle', 'Smart Buy'],
#  ['MILLION LITRES', 'kcnickerson', 'KathleenWynne'],
#  ['ResponseMktg'],
#  ['J. Bee', 'UNCTAD'],
#  ['PrincessBubs_'],
#  ['Nestle', 'NestleHotChoc', 'ColdFront', 'KayPweety', '️'],
#  ['DigitalHealth', 'Nestle'],
#  ['Samsung', 'Nestle', 'SalaamGateway'],
#  ['ali___khan', 'Nestle'],
#  ['Nestle', 'MalikRashidAwan'],
#  ['Nestle', 'pawelkmiec'],
#  ['Nestle', 'VintageDani'],
#  ['drrahmadtufail', 'Nestle Pakistan'],
#  ['DeannaStirling'],
#  ['TheGOPJesus DemoFan', 'Nestle', 'Oregon', 'zeus_bob'],
#  ['Nestle', 'IoT', 'MaltyScotch'],
#  ['Driversng', 'Nigeria', 'JaraMarket Uber Hire'],
#  ['GaryGuitarDude', 'Nestle'],
#  ['CandaceDKitting', 'Nestle', 'Virginia'],
#  ['SolarImpulse', 'Nestle'],
#  ['Nomedialies'],
#  ['NewFoodMag', 'Nestle'],
#  ['Nestle', 'BIG'],
#  ['Nestle', 'em_worley'],
#  ['Nestle', 'VintageDani88'],
#  ['Collaborate', 'Digital Health and Nutrition', 'Nestle', 'Health_FF'],
#  ['Nestle This', 'CastillaLaMancha', 'INVillacanas'],
#  ['granfem'],
#  ['TeachFirst', 'Nestle', 'Andrew_TAP', 'PwCUK'],
#  ['Nestle PackPlus', 'Rajvanshi', 'Suggest', 'HarveerSahni', 'Conclave'],
#  ['emmavincentuk', 'Nestle'],
#  ['Samsung', 'Coline_Letourmy', 'Nestle  Nestlé'],
#  ['0cruelty', 'US'],
#  ['l_stavropoulou', 'DigitalHealth   Nutrition', 'Samsung', 'Nestle'],
#  ['DheepJoy', 'Nestle'],
#  ['Nestle', 'vividbrand'],
#  ['anneroberts_au', 'PalmOilKills RT'],
#  ['sebastianhrw', 'Samsung Partnership', 'IoT', 'Nestle'],
#  ['Nestle', 'Honey Cornflakes', 'abresslour', 'USA', 'UK'],
#  ['Dprang'],
#  ['Nestle', 'MarkMontano'],
#  ['AshleyRTweets', 'KathleenWynne'],
#  ['BChang1978'],
#  ['dleehcassel2'],
#  ['PalmOilKills RT', 'YarosisNancy'],
#  ['sweetride15'],
#  ['candyshae', 'Nestle'],
#  ['DemoFan24', 'Nestle', 'Block Me', 'TheGOPJesus'],
#  ['golfaddictionuk', 'WoburnGC', 'Nestle'],
#  ['NewFoodMag', 'Nestle'],
#  ['Nestle', 'GeorgeCWang'],
#  ['Nestle', 'bleddyn_rees', 'ECHAlliance'],
#  ['Nestle', 'bethporch94'],
#  ['Nestle', 'TQTan0Li', 'Pakistan', 'Hay Nestle'],
#  ['DunnDunny', 'UK'],
#  ['Nestle', 'nycityadchick'],
#  ['HELPMOMSBREASTFEED', 'Nestle', 'ashmanu'],
#  ['Nestle', 'ashmanu'],
#  ['SharleneHinds'],
#  ['NEVER', 'StudentMinSadie', 'Nestle'],
#  ['Nestle'],
#  ['Awareness', 'Afeeratahseen1', 'NESTLESHSHPak Nestle', 'Invitation Thanks'],
#  ['StudentMinSadie', 'Nestle'],
#  ['Data Command Center', 'Nestle First', '1angrymuffin'],
#  ['Rootie261', 'Mint Crisp Ice Lollies', 'Nestle'],
#  ['The1DM', 'Nestle'],
#  ['Rs', 'world1consult', 'NestleIndia'],
#  ['MetisSage1'],
#  ['cplattc'],
#  ['geonal', 'Nestles Milo'],
#  ['Nestle', 'Italian', 'Rumantsch', 'AndaAndrijanic', 'Switzerland'],
#  ['BarcampTamale', 'Nestle GH'],
#  ['InternetofThings', 'Nestle', 'ConnectedLife', 'AnnaRibeiro9'],
#  ['Nestle', 'aakanksha3131'],
#  ['Nestle', 'aakanksha3131'],
#  ['da_real_chinese'],
#  ['InternetofThings', 'IoTInnovator', 'AnnaRibeiro', 'Nestle'],
#  ['DevonG111', 'Nestle'],
#  ['NOMUChirps', 'Nestle', 'SandiSplash', 'Foodies'],
#  ['Thairalumen'],
#  ['Thairalumen'],
#  ['AfterEightUK.Increase', 'Thairalumen', 'QualityStreet'],
#  ['DigitalHealth', 'Nestle'],
#  ['Thairalumen'],
#  ['Nestle', 'Pakistan', 'Amnaa_tariq'],
#  ['Thairalumen', 'Cerelac'],
#  ['Plattform', 'Codourey', 'Samsung Check Nestle', 'healthetia'],
#  ['tymoo_ch', 'Nestle'],
#  ['Nestle', 'immiemalik', 'Fungus'],
#  ['YouTube Watch', 'Nestle', 'allthatsmomblog'],
#  ['BOYCOTT', 'TheGOPJesus'],
#  ['Nestle', 'allthatsmomblog', 'Geetika Gangwani'],
#  ['Nestle', 'allthatsmomblog'],
#  ['Nestle', 'Bharati09', 'EU'],
#  ['mtpwilkinson', 'UK', 'Nestle KITKAT'],
#  ['Rs', 'MaggiIndia', 'ETBrandEquity', 'India'],
#  ['2brandy'],
#  ['Nestle', 'Swiss', 'NFLNCAABarbie'],
#  ['Jaguargetaway'],
#  ['jsonenshine', 'Nestle', 'Unilever'],
#  ['Nestle', 'em_macdonald11'],
#  ['Hall4Justice'],
#  ['ATT', 'portada_online', 'Portada Nestlé'],
#  ['humanwavedotcom'],
#  ['BrandLoveLLC', 'Nestle MayoClinic CMIContent', 'Handle Negative Feedback'],
#  ['suzannecohen01', 'DigitalHealth', 'Samsung Nestle'],
#  ['Nestle'],
#  ['Cacao', 'VirgenFJ', 'Nestle'],
#  ['HomeInOshawa'],
#  ['eNetworkMkt', 'Jacobhaley3', 'Nestle'],
#  ['JennyJenny1991'],
#  ['HealthFocused', 'Samsung', 'Nestle Aim', 'JMOTA3', 'Create'],
#  ['Nestle', 'Milo', 'Candee_Leigh', 'Yall', 'Yey'],
#  ['frenchy2910', 'Nestle'],
#  ['_MattStrong', 'OhHenry', 'Nestle NestleUSA 🐶'],
#  ['ShadowCortana', 'Digornio', 'Nestle'],
#  ['Nestle', 'VictorXboxBoy'],
#  ['Nestle', 'VictorXboxBoy'],
#  ['VictorXboxBoy', 'WITOUT'],
#  ['YoungFellazEnt_', 'Nestle'],
#  ['Nestle', 'alexfollicle'],
#  ['Breast', 'Nestle'],
#  ['Tesco', 'JodieCraven', 'OneBomb Ill'],
#  ['JodieCraven', 'Nestle Tesco'],
#  ['Ali_ahsan491', 'PleaseExplain  Ripnestle', 'Nestle'],
#  ['Ali_ahsan491', 'Nestle'],
#  ['JennDittrich'],
#  ['Break',
#   'Kit Kat',
#   'Nestle Social Media',
#   'Susan Dolan GoogleExpertUK',
#   'AlirisZ'],
#  ['Kit Kat', 'GoogleExpertUK', 'Nestle Social Media'],
#  ['Nestle LeverIndia', 'PushkarajKale', 'Patanjali'],
#  ['AntiDietCoach', 'Nestle'],
#  ['tommstoddart', 'FUCK'],
#  ['MissLesty', 'Tell Nestle'],
#  ['SolarImpulse', 'Nestle'],
#  ['dre_65', 'Tell Nestle'],
#  ['Shahramhaq', 'Nestle'],
#  ['Tell Nestle', 'JoUnrau'],
#  ['Omega', 'Nestle', 'Yumm', 'MisheyMaseh'],
#  ['IoT Devices', 'Create HealthFocused', 'News18Tech'],
#  ['foodtechinvest', 'FutureFoodTech London', 'Scott Parkinson', 'Nestle'],
#  ['Nestle', 'Ist', 'yasminemotarjem', 'Corporate'],
#  ['NestleYour', 'yasminemotarjem'],
#  ['Journalists', 'Nestle U', 'yasminemotarjem'],
#  ['Mobbing', 'Staff', 'yasminemotarjem', 'Nestle Ist'],
#  ['yasminemotarjem', 'Nestle Ist'],
#  ['Corporate', 'yasminemotarjem', 'Nestle Ist'],
#  ['Nestle', 'yasminemotarjem'],
#  ['Nestle Nothing', 'yasminemotarjem', 'Nestle'],
#  ['allthatsmomblog'],
#  ['jcstars22'],
#  ['elviliana_', 'Milo Nestle'],
#  ['Lybio', 'Nestle Superbabies'],
#  ['R2LOGIK'],
#  ['AdisRapidPlus'],
#  ['BruinieBear', 'Tell Nestle'],
#  ['Nestle Neozeloandeaz Britains Goodrich FIRENZE', 'AladimIlumina'],
#  ['ArthurPPrice'],
#  ['BeckiBo2912', 'Nestle', '😢'],
#  ['JasonASpence', 'Fuck Nestle'],
#  ['Brohnly', 'Yo Nestle'],
#  ['Samsung', 'SamsungNewsUS', 'IoT', 'Nestle'],
#  ['AmerDonya', 'Nestle'],
#  ['Kitkat', 'SueandGarry', 'Nestle'],
#  ['Fredric_Ward', 'TysonFoods'],
#  ['Gods', 'Nestle Caramac Giant Buttons', 'SaraSjfoster'],
#  ['Nestle', 'Assam', 'DoubleRotti'],
#  ['TheLongevityNet'],
#  ['WorldBreastfeedingWeek', 'Nestle', 'adelearmstron11'],
#  ['100Fists', 'Nestle'],
#  ['100Fists', 'Nestle'],
#  ['intercodec'],
#  ['Nestle', 'adelearmstron11'],
#  ['Nestle YorkshireTea', 'YorkLass_CC'],
#  ['Superbabies', 'Nestle', 'WorldBreastFeedingWeek'],
#  ['NPL', 'Nestle', 'NestleCare'],
#  ['Chernandez', 'Nestle', '🙄🙄🙄🙄🙄🙄', 'kaylalalarson6'],
#  ['Nestle', 'YorkshireTea', 'YorkLass_CC'],
#  ['.Nestle', 'PLCseniorliving'],
#  ['GMOs', 'NotInMyFood'],
#  ['BakerTheBest_'],
#  ['Rs', 'Off MRP Rs', 'DealYaNoDeal'],
#  ['.Nestle', 'KyleLukan', 'Salesforce'],
#  ['.Nestle', 'adage', 'Salesforce'],
#  ['Salesforce Ad Age', 'Nestle', 'Digital', 'DKrajicekGfK'],
#  ['alianzo', 'Linkedin'],
#  ['LukeSanchez2', 'Nestle Purina'],
#  ['fabnewslive',
#   'World of  Nutrition',
#   'FSMCreative',
#   'Nestle Australia Creates'],
#  ['yourbrandma', 'Nestle'],
#  ['CADBURY NBPLC', 'Stocks', 'TheAnalystNG'],
#  ['Particeep'],
#  ['jjmcewan'],
#  ['Nestle', 'African', 'trutherbotpink'],
#  ['Nestle GymAustralia', 'DevelopChamps', 'sillybilly114'],
#  ['OEWA',
#   'NestleNigeria',
#   'KennethIgbomor',
#   'DharneshGordhon',
#   'Nestle Nigeria'],
#  ['Nestle', 'nestlepakistan'],
#  ['Nestle', 'nestlepakistan'],
#  ['Drifter', 'NestleUKNews', 'U', 'jjmcewan'],
#  ['nestlepakistan'],
#  ['Nestle'],
#  ['Samsung', 'minsungseankim', 'Nestle'],
#  ['Nestle',
#   'European  Innovation Recognition Award',
#   'Smurfit Kappa',
#   'smurfitkappa'],
#  ['ACCESS', 'PMO', 'VBA', 'asiawebmediaa', 'MACRO', 'Business  Analyst'],
#  ['Toffee Crisp', 'jamieiainkirk', 'NestleCerealsUK Nestle'],
#  ['johndionido'],
#  ['Superbabies', 'Nestle', 'WorldBreastFeedingWeek'],
#  ['Nestle', 'Salesforce With New Digital Lab', 'niteshsfdcm', 'Cozying Up'],
#  ['reddindenver'],
#  ['Nestle NestleUKNews', 'M4rkH4mi1t0n', 'UK'],
#  ['anneroberts_au', 'PalmOilKills RT'],
#  ['kyote9', 'Nestle'],
#  ['KonnectInsights', 'Nestle'],
#  ['IoT Devices', 'Create HealthFocused', 'CyCronIndia', 'Nestle Aim'],
#  ['IoT devices', 'guizzettiassoc'],
#  ['davo7the7poet7'],
#  ['Runts Nestle', 'SJohnson4OSU'],
#  ['Its  Marketing by Setting Up Shop', 'Fuller_Creative'],
#  ['Nestle', 'Waitsburg', 'Walt Gobel', 'GalenEttlin'],
#  ['amerlekelly'],
#  ['Ethiopia', 'Nestle', 'trutherbotgreen'],
#  ['Conf', 'Nestle', 'PIMCGIAR IFPRImedia', 'CrawfordFund'],
#  ['Nestle', 'JenniferKillick'],
#  ['The Crunchy Nut Cornflakes', 'JenniferKillick', 'Nestle Ooh'],
#  ['Nestle MattConnors', 'NestleTandem'],
#  ['NestleTandem', 's_thome14'],
#  ['uisgebeatha', 'Nestle'],
#  ['uisgebeatha', 'Nestle AWAAAARGHHHYERNOTSERIEURRGHS'],
#  ['NationalIceCreamSandwichDay', 'NestleTandem', 'Tandem', 'Nestle'],
#  ['uisgebeatha', 'Nestle', 'the Rylan GIF'],
#  ['NestleTandem', 'Tandem', 'Nestle'],
#  ['CiffyvanLooadoo'],
#  ['RD', 'NJ', 'ChooseNJ', 'DYK Nestle', 'HQ'],
#  ['xXPrincessDanXx'],
#  ['moonreflections'],
#  ['Samsung', 'GCattaneo_', 'Nestle'],
#  ['faithcameletti', 'KathleenWynne'],
#  ['BandanaEvan', 'Nestle Tandem', 'NestleTandem'],
#  ['Nestle Tandem', 'NestleTandem'],
#  ['MattConnors', 'Nestle Tandem', 'NestleTandem'],
#  ['Nestle', 'TheTiteReport'],
#  ['PalmOilKills RT', 'Animantium1'],
#  ['BrightBlueStang', 'Nestle SnoCaps'],
#  ['ManufacturingGL', 'Samsung  ICYMI', 'Nestle'],
#  ['Nestle Toll House', 'gacarol18'],
#  ['lesaann98', 'Nestle'],
#  ['steen1969', 'Samsung Nestle'],
#  ['Nestle Triple', 'SharpCheddar856'],
#  ['Nestle Toll House', 'gacarol18'],
#  ['TheresaSigourne', 'WDWwithCourtney'],
#  ['MomsTakinABreak'],
#  ['TheresaSigourne', 'Nestle Toll House'],
#  ['melanielaquerre', 'KathleenWynne Stop'],
#  ['PreachIt Riggs', 'Popsicle Hersheys Nestle', 'chimpsfall75'],
#  ['ConsciousCapATX'],
#  ['Samsung', 'TheDukeDigital'],
#  ['Superbabies', 'Nestle', 'WorldBreastFeedingWeek'],
#  ['NationalIceCreamSandwichDay', 'Nestle Tandem', 'NestleTandem'],
#  ['ManufacturingGL', 'Samsung', 'Nestle'],
#  ['Samsung', 'BizClikNell', 'Nestle'],
#  ['IronMikeElse', 'Nestle'],
#  ['AvalancheOnMars', 'Nestle', 'Gatorade'],
#  ['Popsicle Hersheys Nestle', 'JLuv81'],
#  ['Hersheys', 'Nestle', 'johnblueriggs', 'Popsicle'],
#  ['San Pellegrino', 'Nestle', 'KDM1039'],
#  ['Ch0coBars', 'Nestle', 'Tryrone'],
#  ['China', 'Nestle', 'Nescafé'],
#  ['Nestle European', 'EFIA2'],
#  ['Milo', 'PrinceofSydney'],
#  ['.Nestle', 'Rethink_IoT'],
#  ['Samsung', 'Health', 'JohnTheMap', 'Nestle'],
#  ['Nestle'],
#  ['RavS82', 'Institute of Human Resource', 'Elijah Sitima', 'Nestle'],
#  ['Brazil', 'Nestle', 'US', 'assuncao_carla'],
#  ['Nestle', 'vprince379'],
#  ['Nestle Discoloured', 'vprince379'],
#  ['Nestle'],
#  ['Lagos', 'Nestle NestleCWAR', 'Nigeria', 'Dunga52'],
#  ['Samsung', 'PandaINT_rec', 'Nestle', 'SamsungNewsroom'],
#  ['Singapore', 'kristynnika', 'Australia', 'Nigeria'],
#  ['Nestle', '18Smartygirl'],
#  ['HistoryPrepared', 'RobertLopezUK'],
#  ['CallinU0ut', 'Nestle'],
#  ['Australian', 'Retro Party Mix', 'md3obrien', 'Nestle'],
#  ['Nestle'],
#  ['Nestle Flipkart', 'world1consult'],
#  ['trutherbotblue', 'Nestle'],
#  ['TheLensbury', 'ncmediatv', 'Nestle'],
#  ['MTROUTcom'],
#  ['Nestle', 'SimonBotting'],
#  ['Nestle', 'iarslanakbar'],
#  ['BDS', 'Nestle', 'likeits2015', 'McDonalds CocaCola', 'CNN'],
#  ['Nestle one', 'Nestle', 'Pak', 'Pakistan', 'iarslanakbar'],
#  ['Nestle', 'iarslanakbar'],
#  ['Nestle', 'iarslanakbar'],
#  ['abrar_kureshy', 'MaleehaBaluch', 'Nestle'],
#  ['Maleeha_Baluch', 'Nestle'],
#  ['abrar_kureshy', 'MaleehaBaluch', 'Nestle'],
#  ['Nestle', 'iarslanakbar', 'House'],
#  ['Nestle  Pakistan', 'Maleeha_Baluch'],
#  ['pichkee', 'Pakistan', 'Nestle'],
#  ['Islamabad', 'Nestle', 'iarslanakbar'],
#  ['Pakistan Health', 'Maleeha_Baluch', 'Islamabad Nestle', 'UKHAajse'],
#  ['pichkee', 'Nestle', 'AAJ', 'United'],
#  ['pichkee', 'Nestle'],
#  ['anneroberts_au', 'PalmOilKills RT'],
#  ['Nestle',
#   'Milo',
#   'Jacques Reber',
#   'Build bPeso Protomalt Plant',
#   'itradeph',
#   'Philippines'],
#  ['micBring', 'mjoverbeck'],
#  ['Nestle Its', 'OccupyPhotojour', 'Interlaken'],
#  ['Nestle Nigeria Plc', 'Negative', 'proshare'],
#  ['BoyCott NestleUSA',
#   'GMOfoods',
#   'Nestle HIDE',
#   'Pepesplants',
#   'maxrafaelwaller'],
#  ['OUR Food System', 'FarmFairyCrafts'],
#  ['kaykryssal'],
#  ['Catheri TaijiDAG', 'TheGOPJesus'],
#  ['Globalworrier', 'TheGOPJesus'],
#  ['KNOW', 'AuliCarl', 'KwikfituTim BungeeWedgie', 'TheGOPJesus'],
#  ['BOYCOTT Nestle', 'GrainOfSands', 'TheGOPJesus', 'HURT US'],
#  ['GrabschDagmar', 'Nestle'],
#  ['GrabschDagmar', 'Nestles'],
#  ['Cascade Locks', 'Nestle', 'USA', 'Oregon', 'ECORIBOR'],
#  ['guy_glenmor', 'Nestle Fonterra Chalkcheese'],
#  ['MARTINRANGER'],
#  ['Blt0lcanka', 'Nestle'],
#  ['PalmOilKills RT', 'moodysally1'],
#  ['Nestle', 'jshemenski'],
#  ['gm_palmer', 'Nestle'],
#  ['NutriFusion', 'Nestle'],
#  ['Nestle', 'SmllTwnIdiot'],
#  ['Crozierkid'],
#  ['OneLoveCocoa', 'Nestle NibsnScribs'],
#  ['OneLoveCocoa', 'Hmm', 'Nestle NibsnScribs'],
#  ['PurinaCareers Nestle', 'skau61'],
#  ['Nestle NibsnScribs', 'daisychaindream'],
#  ['Nestle', 'dbrown94'],
#  ['KaylaMarls', 'Nestle 😭'],
#  ['bignumberone', 'Nestle Great'],
#  ['NestleUKNews Nestle', 'NibsnScribs', '🙌'],
#  ['ktkehoe'],
#  ['daisychaindream', 'NestleUKNews Nestle NibsnScribs'],
#  ['CanadianGuy2018'],
#  ['rosachwalek'],
#  ['BOYCOTT Nestle Blocking',
#   'Labeling!VirginiaInCal',
#   'FarmFairyCrafts',
#   'LLaws'],
#  ['SarahFrangos1', '🤔'],
#  ['qwfwk_allisonc'],
#  ['rsbasavaraj711'],
#  ['shespeaksup', 'SheSpeaksTV', 'Nestle Watch'],
#  ['petedako', 'cdnPoli', 'KathleenWynne', 'Stop Nestlé'],
#  ['VisionKeepersTV', 'China'],
#  ['bignumberone'],
#  ['bignumberone', 'Nestle'],
#  ['Nestle', 'valerie_tk1'],
#  ['NV',
#   'JRybka4177',
#   'Globalworrier HaroldWNelson',
#   'Nestle Libertea',
#   'TheGOPJesus'],
#  ['Globalworrier HaroldWNelson',
#   'Libertea JRybka',
#   'TheGOPJesus',
#   'rosevine3'],
#  ['Nestle'],
#  ['Nestle', 'KontikiBizVideo'],
#  ['PalmOilKills RT', 'No2Speciesism1'],
#  ['JonWickett', 'mathsDK', 'Nestle'],
#  ['Catheri TaijiDAG', 'rosevine3'],
#  ['Globalworrier HaroldWNelson',
#   'Nestle Libertea',
#   'TheGOPJesus',
#   'JRybka4177'],
#  ['coracupcakes', 'Nestle'],
#  ['BOYCOTT Nestle SAY',
#   'VillageIdiot PhotoByPixie',
#   'TheGOPJesus MadagioPepe',
#   'rosevine3'],
#  ['mathsDK', 'Nestle Have'],
#  ['TheGOPJesus Nestle', 'GrannyRevHub'],
#  ['BOYCOTT Nestle', 'Globalworrier', 'rosevine3'],
#  ['KNOW', 'AuliCarl', 'TheGOPJesus KwikfituTim BungeeWedgie', 'rosevine3'],
#  ['NestleWatersNA', 'sherrylynn914', 'Nestea'],
#  ['PalmOilKills RT', 'YarosisNancy'],
#  ['GrainOfSands', 'HURT US', 'rosevine3'],
#  ['FarmFairyCrafts', 'OrganicsFree'],
#  ['Nerds', 'Nestle', 'noahonair'],
#  ['dano708', 'Nestle'],
#  ['Milky Bar Mousse', 'NibsnScribs', 'NEW REVIEW'],
#  ['SVInitiative', 'RT Nestle Ending'],
#  ['agoss1'],
#  ['Lindaferns', 'JohnRobbie', 'TigerBrands', 'Nestle'],
#  ['RT VirginiaInCal', 'rosevine3'],
#  ['mommapollock'],
#  ['NestleIndia Nestle', 'TheMrsAss'],
#  ['PalmOilKills RT', 'CyntWhite'],
#  ['Pharma company', 'VelocityBG', 'Nestle'],
#  ['activist_agenda', 'Maine', 'Nestle'],
#  ['Nestle'],
#  ['wpt_cruiseone', 'Nestle', 'BritaUSA'],
#  ['🐶', 'Nestle'],
#  ['Nestle', 'MarkMontano'],
#  ['LlewPaul'],
#  ['MarieSnyder27'],
#  ['Nestle'],
#  ['GrabschDagmar', 'PalmOilKills RT'],
#  ['Nestle', 'NestleEU Nestle', 'Nestle_IDN', 'Indonesia', 'Nestlé'],
#  ['jpadams'],
#  ['Milo', 'Lipa', 'Batangas', 'interaksyon'],
#  ['PalmOilKills RT', 'OpKillerPalm'],
#  ['hannahblake123', 'Nestle'],
#  ['FoodGrads'],
#  ['Nestle', 'manuelnappo'],
#  ['😩', 'devine__'],
#  ['Paid  Internship Nestle', 'Application Link', 'wemakescholars'],
#  ['MouradSarroub'],
#  ['Nestle', 'JoseManuelRanz'],
#  ['Nestle', 'ThingsCity'],
#  ['specialk2480', 'Nestle'],
#  ['whiteguy1980', 'Nestle'],
#  ['KeckersT', 'MacIntosh Cabana'],
#  ['Nestle', 'MarkMontano'],
#  ['Nestle', 'WorldBreastFeedingWeek'],
#  ['Nestle', 'DirkJacobsEU'],
#  ['Nestle', 'HAR'],
#  ['Samsung', 'InsideFoodMag', 'Nestlé', 'Nestle'],
#  ['.Nestle', 'dandad', 'JWTWorldwide'],
#  ['MidwivesExc', 'Nestle The Superbabies'],
#  ['Nestle', 'valerie_tk1'],
#  ['Nestle', 'valerie_tk1'],
#  ['Australia', 'Nestle', 'MILO'],
#  ['Nestle', 'WorldBreastFeedingWeek'],
#  ['FarmFairyCrafts', 'OrganicsFree'],
#  ['NestléUKNews', 'Nestle', 'SharedValue'],
#  ['anneroberts_au', 'PalmOilKills RT'],
#  ['Nestle'],
#  ['Hikayori'],
#  ['Maggis', 'ETBrandEquity', 'MaggiIndia Nestle Read', 'Nestles'],
#  ['NestleTandem', 'Tandem', 'Nestle'],
#  ['Nestle', 'allthatsmomblog'],
#  ['IndustryARC', 'AnheuserBusch', 'Nestle DrinkAriZona'],
#  ['ambantatua'],
#  ['Nestle', 'Nestlefor', 'BGCKC'],
#  ['Butterfinger', 'Nestle', 'J_Drew23', 'Momma Joyce'],
#  ['Nestle BoycottNestle', 'breastfdscience'],
#  ['wBW', 'Nestle', 'breastfdscience'],
#  ['RManning47'],
#  ['aophiuchus', 'Nestle RepAdamSchiff'],
#  ['Nestle', 'OasisPatersonNJ'],
#  ['BgcRadio'],
#  ['Nestlefor', 'Stephyounan', 'Nestle NestleUSA'],
#  ['BradHeyden', 'Nestle  Splash'],
#  ['Milky Way', 'EmilyThorne'],
#  ['Nestle', 'bullseyeant'],
#  ['SugarLafever', 'Saw', 'Buyer'],
#  ['Grillocracy', 'Smoked Chocolate Chips'],
#  ['LiveClareLesley'],
#  ['Superbabies', 'Nestle', 'WorldBreastFeedingWeek'],
#  ['Anniversary', 'Nestle', 'Gerber', 'YCSCares'],
#  ...]

# %%
te_ary = te.fit(ent_list).transform(ent_list)

# %%
ent_df = pd.DataFrame(te_ary,columns=te.columns_)
ent_df
# Out:
#        .ARCSouthAfrica  .GeneralMills  .KathleenWynne  .Nestle  \
# 0      False            False          False           False
# 1      False            False          False           False
# 2      False            False          False           False
# 3      False            False          False           False
# 4      False            False          False           False
# 5      False            False          False           False
# 6      False            False          False           False
# 7      False            False          False           False
# 8      False            False          False           False
# 9      False            False          False           False
# 10     False            False          False           False
# 11     False            False          False           False
# 12     False            False          False           False
# 13     False            False          False           False
# 14     False            False          False           False
# 15     False            False          False           False
# 16     False            False          False           False
# 17     False            False          False           False
# 18     False            False          False           False
# 19     False            False          False           False
# 20     False            False          False           False
# 21     False            False          False           False
# 22     False            False          False           False
# 23     False            False          False           False
# 24     False            False          False           False
# 25     False            False          False           False
# 26     False            False          False           False
# 27     False            False          False           False
# 28     False            False          False           False
# 29     False            False          False           False
# ...      ...              ...            ...             ...
# 17077  False            False          False           False
# 17078  False            False          False           False
# 17079  False            False          False           False
# 17080  False            False          False           False
# 17081  False            False          False           False
# 17082  False            False          False           False
# 17083  False            False          False           False
# 17084  False            False          False           False
# 17085  False            False          False           False
# 17086  False            False          False           False
# 17087  False            False          False           False
# 17088  False            False          False           False
# 17089  False            False          False           False
# 17090  False            False          False           False
# 17091  False            False          False           False
# 17092  False            False          False           False
# 17093  False            False          False           False
# 17094  False            False          False           False
# 17095  False            False          False           False
# 17096  False            False          False           False
# 17097  False            False          False           False
# 17098  False            False          False           False
# 17099  False            False          False           False
# 17100  False            False          False           False
# 17101  False            False          False           False
# 17102  False            False          False           False
# 17103  False            False          False           False
# 17104  False            False          False           False
# 17105  False            False          False           False
# 17106  False            False          False           False
#
#        .Nestle  Grand Bars  .Nestle S.A.  .SafewayCanada  .nestle  000_gf  \
# 0      False                False         False           False    False
# 1      False                False         False           False    False
# 2      False                False         False           False    False
# 3      False                False         False           False    False
# 4      False                False         False           False    False
# 5      False                False         False           False    False
# 6      False                False         False           False    False
# 7      False                False         False           False    False
# 8      False                False         False           False    False
# 9      False                False         False           False    False
# 10     False                False         False           False    False
# 11     False                False         False           False    False
# 12     False                False         False           False    False
# 13     False                False         False           False    False
# 14     False                False         False           False    False
# 15     False                False         False           False    False
# 16     False                False         False           False    False
# 17     False                False         False           False    False
# 18     False                False         False           False    False
# 19     False                False         False           False    False
# 20     False                False         False           False    False
# 21     False                False         False           False    False
# 22     False                False         False           False    False
# 23     False                False         False           False    False
# 24     False                False         False           False    False
# 25     False                False         False           False    False
# 26     False                False         False           False    False
# 27     False                False         False           False    False
# 28     False                False         False           False    False
# 29     False                False         False           False    False
# ...      ...                  ...           ...             ...      ...
# 17077  False                False         False           False    False
# 17078  False                False         False           False    False
# 17079  False                False         False           False    False
# 17080  False                False         False           False    False
# 17081  False                False         False           False    False
# 17082  False                False         False           False    False
# 17083  False                False         False           False    False
# 17084  False                False         False           False    False
# 17085  False                False         False           False    False
# 17086  False                False         False           False    False
# 17087  False                False         False           False    False
# 17088  False                False         False           False    False
# 17089  False                False         False           False    False
# 17090  False                False         False           False    False
# 17091  False                False         False           False    False
# 17092  False                False         False           False    False
# 17093  False                False         False           False    False
# 17094  False                False         False           False    False
# 17095  False                False         False           False    False
# 17096  False                False         False           False    False
# 17097  False                False         False           False    False
# 17098  False                False         False           False    False
# 17099  False                False         False           False    False
# 17100  False                False         False           False    False
# 17101  False                False         False           False    False
# 17102  False                False         False           False    False
# 17103  False                False         False           False    False
# 17104  False                False         False           False    False
# 17105  False                False         False           False    False
# 17106  False                False         False           False    False
#
#        007RrAaYy  ...        🙈     🙈😈      🙌     🙌🏻  🙌🙌👏👏👏      🙏      🛇  \
# 0      False      ...    False  False  False  False  False  False  False
# 1      False      ...    False  False  False  False  False  False  False
# 2      False      ...    False  False  False  False  False  False  False
# 3      False      ...    False  False  False  False  False  False  False
# 4      False      ...    False  False  False  False  False  False  False
# 5      False      ...    False  False  False  False  False  False  False
# 6      False      ...    False  False  False  False  False  False  False
# 7      False      ...    False  False  False  False  False  False  False
# 8      False      ...    False  False  False  False  False  False  False
# 9      False      ...    False  False  False  False  False  False  False
# 10     False      ...    False  False  False  False  False  False  False
# 11     False      ...    False  False  False  False  False  False  False
# 12     False      ...    False  False  False  False  False  False  False
# 13     False      ...    False  False  False  False  False  False  False
# 14     False      ...    False  False  False  False  False  False  False
# 15     False      ...    False  False  False  False  False  False  False
# 16     False      ...    False  False  False  False  False  False  False
# 17     False      ...    False  False  False  False  False  False  False
# 18     False      ...    False  False  False  False  False  False  False
# 19     False      ...    False  False  False  False  False  False  False
# 20     False      ...    False  False  False  False  False  False  False
# 21     False      ...    False  False  False  False  False  False  False
# 22     False      ...    False  False  False  False  False  False  False
# 23     False      ...    False  False  False  False  False  False  False
# 24     False      ...    False  False  False  False  False  False  False
# 25     False      ...    False  False  False  False  False  False  False
# 26     False      ...    False  False  False  False  False  False  False
# 27     False      ...    False  False  False  False  False  False  False
# 28     False      ...    False  False  False  False  False  False  False
# 29     False      ...    False  False  False  False  False  False  False
# ...      ...      ...      ...    ...    ...    ...    ...    ...    ...
# 17077  False      ...    False  False  False  False  False  False  False
# 17078  False      ...    False  False  False  False  False  False  False
# 17079  False      ...    False  False  False  False  False  False  False
# 17080  False      ...    False  False  False  False  False  False  False
# 17081  False      ...    False  False  False  False  False  False  False
# 17082  False      ...    False  False  False  False  False  False  False
# 17083  False      ...    False  False  False  False  False  False  False
# 17084  False      ...    False  False  False  False  False  False  False
# 17085  False      ...    False  False  False  False  False  False  False
# 17086  False      ...    False  False  False  False  False  False  False
# 17087  False      ...    False  False  False  False  False  False  False
# 17088  False      ...    False  False  False  False  False  False  False
# 17089  False      ...    False  False  False  False  False  False  False
# 17090  False      ...    False  False  False  False  False  False  False
# 17091  False      ...    False  False  False  False  False  False  False
# 17092  False      ...    False  False  False  False  False  False  False
# 17093  False      ...    False  False  False  False  False  False  False
# 17094  False      ...    False  False  False  False  False  False  False
# 17095  False      ...    False  False  False  False  False  False  False
# 17096  False      ...    False  False  False  False  False  False  False
# 17097  False      ...    False  False  False  False  False  False  False
# 17098  False      ...    False  False  False  False  False  False  False
# 17099  False      ...    False  False  False  False  False  False  False
# 17100  False      ...    False  False  False  False  False  False  False
# 17101  False      ...    False  False  False  False  False  False  False
# 17102  False      ...    False  False  False  False  False  False  False
# 17103  False      ...    False  False  False  False  False  False  False
# 17104  False      ...    False  False  False  False  False  False  False
# 17105  False      ...    False  False  False  False  False  False  False
# 17106  False      ...    False  False  False  False  False  False  False
#
#            🤔  🤔 Found     🤔🙈
# 0      False  False    False
# 1      False  False    False
# 2      False  False    False
# 3      False  False    False
# 4      False  False    False
# 5      False  False    False
# 6      False  False    False
# 7      False  False    False
# 8      False  False    False
# 9      False  False    False
# 10     False  False    False
# 11     False  False    False
# 12     False  False    False
# 13     False  False    False
# 14     False  False    False
# 15     False  False    False
# 16     False  False    False
# 17     False  False    False
# 18     False  False    False
# 19     False  False    False
# 20     False  False    False
# 21     False  False    False
# 22     False  False    False
# 23     False  False    False
# 24     False  False    False
# 25     False  False    False
# 26     False  False    False
# 27     False  False    False
# 28     False  False    False
# 29     False  False    False
# ...      ...    ...      ...
# 17077  False  False    False
# 17078  False  False    False
# 17079  False  False    False
# 17080  False  False    False
# 17081  False  False    False
# 17082  False  False    False
# 17083  False  False    False
# 17084  False  False    False
# 17085  False  False    False
# 17086  False  False    False
# 17087  False  False    False
# 17088  False  False    False
# 17089  False  False    False
# 17090  False  False    False
# 17091  False  False    False
# 17092  False  False    False
# 17093  False  False    False
# 17094  False  False    False
# 17095  False  False    False
# 17096  False  False    False
# 17097  False  False    False
# 17098  False  False    False
# 17099  False  False    False
# 17100  False  False    False
# 17101  False  False    False
# 17102  False  False    False
# 17103  False  False    False
# 17104  False  False    False
# 17105  False  False    False
# 17106  False  False    False
#
# [17107 rows x 19298 columns]

# %%
ent_df.shape
# Out:
# (17107, 19298)

# %%
def frange(start, stop, step):
    i = start
    while i > stop:
        yield i
        i -= step

# %%
def apriori_w_adjusted_min_support(ent_df):
    full_range = list(frange(0.9,0.1,0.1)) + list(frange(0.09,0.01,0.01)) + list(frange(0.009,0.001,0.001))
    for i in full_range:
        threshold = round(i,3)
        frequent_ents = apriori(ent_df,min_support=threshold,use_colnames=True)
        if len(frequent_ents) > 20:
            print("min_support:{}".format(round(i,3)))
            return frequent_ents
    return frequent_ents

#frequent_ents = apriori(ent_df,min_support=0.7,use_colnames=True)
frequent_ents = apriori_w_adjusted_min_support(ent_df)
# Out:
# min_support:0.004

# %%
#frequent_ents = apriori(ent_df,min_support=0.01,use_colnames=True)
frequent_ents
# Out:
#      support                  itemsets
# 0   0.061320  (.Nestle)
# 1   0.012509  (BATPress)
# 2   0.021629  (BATpress)
# 3   0.007541  (KITKAT)
# 4   0.004092  (KathleenWynne Stop)
# 5   0.144444  (Michigan)
# 6   0.387035  (Nestle)
# 7   0.052844  (Nestle M)
# 8   0.006196  (Nestle ModernDayMoms)
# 9   0.005144  (Nestles)
# 10  0.004910  (Nestlé)
# 11  0.004384  (Ontario)
# 12  0.005436  (PalmOilKills RT)
# 13  0.040217  (Tell Nestle)
# 14  0.005612  (TheGOPJesus)
# 15  0.005846  (Unilever)
# 16  0.007716  (WalmartLive)
# 17  0.004735  (YourLifeInFood)
# 18  0.007132  (rosevine3)
# 19  0.012276  (.Nestle, BATPress)
# 20  0.021512  (Nestle, BATpress)
# 21  0.052142  (Michigan, Nestle M)
# 22  0.004560  (Nestle, YourLifeInFood)

# %%
as_rules = association_rules(frequent_ents, metric="lift",min_threshold=1)

# %%
as_rules

# %%
key_rules = as_rules[(as_rules["confidence"]>0.7)&(as_rules["lift"]>=1)]
key_rules

# %%
# remove multiple items
def is_single(row):
    if row["antecedents"] is not None and len(row["antecedents"])==1:
        if row["consequents"] is not None and len(row["consequents"])==1:
            return "y"
    return "n"
key_rules["is_single"] = key_rules.apply(is_single,axis=1)

# %%
key_rules

# %%
#key_rules.drop(["is_single"],axis=1,inplace=True)
key_rules = key_rules[key_rules["is_single"]=="y"]
key_rules

# %%
key_rules["source"] = key_rules["antecedents"].apply(lambda x: ','.join(x))
key_rules["target"] = key_rules["consequents"].apply(lambda x: ','.join(x))

# %%
key_rules

# %% [markdown]
# ## Create graph node response

# %%
"""
graph.node = [
    { ID:"@apple", group:1, index:0,name:"apple", px:100, py:100, size:40, weight:100, x:41, y:95},
    { ID:"@orange", group:2, index:1,name:"orange", px:50, py:50, size:10, weight:100, x:200, y:300},
    { ID:"@grape", group:1, index:1,name:"grape", px:200, py:200, size:3, weight:100, x:250, y:150}
  ];
  graph.edge = [
    { 
      source: 1, 
      target: 2,
      value:5
    }
  ];
"""

# %%
antecedents_nodes = key_rules[["source","antecedent support"]]
antecedents_nodes.rename(columns={"source":"node","antecedent support":"support"},inplace=True)
consequents_nodes = key_rules[["target","consequent support"]]
consequents_nodes.rename(columns={"target":"node","consequent support":"support"},inplace=True)
graph_nodes = pd.concat([antecedents_nodes,consequents_nodes])
graph_nodes = graph_nodes.reset_index(drop=True)
graph_nodes

# %%
graph_nodes_dedup = graph_nodes.drop_duplicates(["node"],keep="first")
graph_nodes_dedup = graph_nodes_dedup.reset_index(drop=True)
graph_nodes_dedup

# %%
graph_nodes_dedup

# %%
  """
  { ID:"@apple", group:1, index:0,name:"apple", px:100, py:100, size:40, weight:100, x:41, y:95},
  { ID:"@orange", group:2, index:1,name:"orange", px:50, py:50, size:10, weight:100, x:200, y:300},
  { ID:"@grape", group:1, index:1,name:"grape", px:200, py:200, size:3, weight:100, x:250, y:150}
  """  
graph_nodes_dedup["ID"] = graph_nodes_dedup["node"]
graph_nodes_dedup["group"] = 2
graph_nodes_dedup["index"] = graph_nodes_dedup.index
graph_nodes_dedup["px"] = 100
graph_nodes_dedup["py"] = 100
graph_nodes_dedup["x"] = 100
graph_nodes_dedup["y"] = 100
graph_nodes_dedup["support"] = scaler.fit_transform(graph_nodes_dedup[["support"]])
graph_nodes_dedup["weight"] = 10
graph_nodes_dedup.rename(columns={"node":"name","support":"size"},inplace=True)
graph_nodes_dedup

# %%
graph_node_json = graph_nodes_dedup.to_json(orient='records')
graph_node_json

# %% [markdown]
# ## Create graph link response

# %%
graph_edges = key_rules[["antecedents","consequents","lift"]]
graph_edges.rename(columns={"antecedents":"source","consequents":"target","lift":"value"},inplace=True)
graph_edges

# %%
"""
  source: 1, 
  target: 2,
  value:5
"""
graph_edges["source"] = graph_edges["source"].apply(lambda x: ','.join(x))
graph_edges["target"] = graph_edges["target"].apply(lambda x: ','.join(x))

# %%
graph_edges

# %%
# replace source name with source index
graph_edges_idx = graph_edges.merge(graph_nodes_dedup[["ID","index"]],how="left",left_on="source",right_on="ID")
graph_edges_idx.drop(["source","ID"],axis=1,inplace=True)
graph_edges_idx.rename(columns={"index":"source"},inplace=True)

# %%
# replace target name with target index
graph_edges_idx = graph_edges_idx.merge(graph_nodes_dedup[["ID","index"]],how="left",left_on="target",right_on="ID")
graph_edges_idx.drop(["target","ID"],axis=1,inplace=True)
graph_edges_idx.rename(columns={"index":"target"},inplace=True)
graph_edges_idx

# %%
graph_edge_json = graph_edges_idx.to_json(orient='records')
graph_edge_json
